# %% [markdown]
# # Quelques mots sur l'environnement Python de Kaggle
#
# L'environnement python de Kaggle contient déjà de nombreuses bibliothèques d'analyse utiles :
#
# - Numpy
# - Pandas
# - Matplotlib
# - Seaborn
# - SKLearn
# - ELI5
# - L'environnement est défini par l'image Docker `kaggle/python`. Si vous voulez en savoir plus sur la configuration de l'image cloud sur laquelle vous exécutez votre code, veuillez consulter le repository GitHub.
#
# ## Entrée
# Il n'y a qu'un seul fichier disponible pour la lecture dans ce notebook, le jeu de données German Credit que nous utiliserons lors de notre session pratique.
# Le jeu de données est disponible à `/kaggle/input/german-credit-data-with-risk/german_credit_data.csv`.
#
# ## Sauvegarde de données
# Vous pouvez écrire jusqu'à **20 Go** dans le répertoire courant kaggle/working qui est conservé entre les sessions. C'est-à-dire que la prochaine fois que vous ouvrez ce notebook et démarrez la session, le fichier sera disponible pour vous.
#
# Vous pouvez également écrire des fichiers temporaires dans /kaggle/temp/, mais ils ne seront pas enregistrés en dehors de la session en cours
#
# Raccourcis utiles
# Tous les raccourcis ci-dessous fonctionnent lorsque la cellule cible est sélectionnée (pas lors de l'édition).
#
# - a: pour insérer une cellule au-dessus
# - b: pour insérer une cellule en dessous
# - dd: pour supprimer une cellule
# - m: pour changer la cellule en markdown
# - y: pour changer la cellule en code
# Pour plus de raccourcis, veuillez consulter ce [notebook](https://www.kaggle.com/naushads/keyboard-shortcuts-for-kaggle-kernels).

# %%
data_path = '../02_machine_learning/solution/data'

# %%
# Checking the files available in this notebook 
import os
for dirname, _, filenames in os.walk(data_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../02_machine_learning/solution/data/german_credit_data.csv

# %% [markdown]
# # Contexte: German Credit Rapport
#
# Le jeu de données original contient des entrées avec 20 attributs catégoriels/symboliques préparés par le professeur Hofmann. Dans ce jeu de données, chaque entrée représente une personne qui prend un crédit auprès d'une banque. Chaque personne est classée comme un bon ou un mauvais risque de crédit en fonction de l'ensemble des attributs. Le jeu de données original peut être trouvé [here](https://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29).
#
# Nous utiliserons une version simplifiée du jeu de données avec seulement **9 attributs** dans notre cours.

# %%
### Importation des bibliothèques générales que nous utiliserons dans ce notebook
import numpy as np # algèbre linéaire
import pandas as pd # traitement des données, I/O de fichier CSV (par ex. pd.read_csv)
import seaborn as sns # bibliothèque de tracé qui utilise matplot 
import matplotlib.pyplot as plt # pour tracer certains paramètres dans seaborn

# Reading the dataset
dataset = pd.read_csv(data_path + '/german_credit_data.csv', index_col=None)

# %%
dataset.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
# Nettoyer le jeu de données
dataset = dataset.drop('Unnamed: 0', axis='columns')
dataset.head(n=20)
# Out:
#     Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0    67    male    2     own             NaN           little           1169
# 1    22  female    2     own          little         moderate           5951
# 2    49    male    1     own          little              NaN           2096
# 3    45    male    2    free          little           little           7882
# 4    53    male    2    free          little           little           4870
# 5    35    male    1    free             NaN              NaN           9055
# 6    53    male    2     own      quite rich              NaN           2835
# 7    35    male    3    rent          little         moderate           6948
# 8    61    male    1     own            rich              NaN           3059
# 9    28    male    3     own          little         moderate           5234
# 10   25  female    2    rent          little         moderate           1295
# 11   24  female    2    rent          little           little           4308
# 12   22  female    2     own          little         moderate           1567
# 13   60    male    1     own          little           little           1199
# 14   28  female    2    rent          little           little           1403
# 15   32  female    1     own        moderate           little           1282
# 16   53    male    2     own             NaN              NaN           2424
# 17   25    male    2     own             NaN           little           8072
# 18   44  female    3    free          little         moderate          12579
# 19   31    male    2     own      quite rich              NaN           3430
#
#     Duration              Purpose  Risk
# 0          6             radio/TV  good
# 1         48             radio/TV   bad
# 2         12            education  good
# 3         42  furniture/equipment  good
# 4         24                  car   bad
# 5         36            education  good
# 6         24  furniture/equipment  good
# 7         36                  car  good
# 8         12             radio/TV  good
# 9         30                  car   bad
# 10        12                  car   bad
# 11        48             business   bad
# 12        12             radio/TV  good
# 13        24                  car   bad
# 14        15                  car  good
# 15        24             radio/TV   bad
# 16        24             radio/TV  good
# 17        30             business  good
# 18        24                  car   bad
# 19        24             radio/TV  good

# %% [markdown]
# ## Part 1: Exploring the dataset
#
# 1. Explore the dataset features and the target variable
#  - How much data do we have?
#  - Do we have any missing data? (NaN)
#  - What are the types of features in our dataset?
#  - How is the distribution of the target variable?
#
# Tip: Check out the [Pandas API](https://pandas.pydata.org/) for functions that can help with data exploration.

# %%
# Combien de données avons-nous?
print(f'Nous avons {dataset.shape[0]} lignes et {dataset.shape[1]} colonnes.')

# Avons-nous des données manquantes?


# Quels sont les types de caractéristiques (numériques vs catégorielles) ?


# Quelle est la distribution de la variable `Risk`?
# Out:
# Nous avons 1000 lignes et 10 colonnes.

# %% [markdown]
# Ecrivez vos observations de la Partie 1 ici:
# - Notre jeu de donées a X lignes et Y colonnes
# - [...]

# %% [markdown]
# # Partie 2: Analyse de la distribution et de la relation des caractéristiques (attributs)
#
# Dans cette partie de la session pratique, nous allons explorer la relation entre les caractéristiques et leur distribution respective dans le jeu de données.
# - Avons-nous un jeu de données biaisé?
# - Comment certaines caractéristiques sont-elles liées à un bon/mauvais crédit?

# %%
sns.set_context('talk', font_scale=.9)
# Exemple des types d'analyse qui peuvent être effectués

# Count plot nous aide à visualiser le nombre d'éléments par catégorie
sns.countplot(data=dataset, x='Sex', hue='Risk')
plt.show()

# Box plot nous aide à voir la valeur moyenne d'une catégorie "Sex" par "Age" dans notre jeu de données
sns.catplot(data=dataset, x='Sex', y='Age', kind='box')
plt.show()

# Split violin plots nous aide à comparer la distribution à travers une valeur de teinte "Risk"
sns.violinplot(data=dataset, x='Sex', y='Age', hue='Risk', split=True)
plt.show()

# Displot nous aide à visualiser la distribution avec des histogrammes
sns.displot(data=dataset, row='Sex', y='Purpose', col='Risk')
plt.show()

# %% [markdown]
# # Expérimentez en analysant d'autres caractéristiques dans le jeu de données!
#
# - Contrôle vs Age vs Risk?
# - Compte d'Épargne vs montant de crédit?
# - Que demandent les personnes ayant différents types de compte de contrôle (peu, modéré, riche) pour un crédit?
# - ...

# %%
# Ecrivez votre code ici (vous pouvez réutiliser/copier la plupart du code utilisé au dessus 

# Displot nous aide à visualiser la distribution avec des histogrammes
# sns.displot(data=dataset, row='Purpose', y='Credit amount', col='Risk')
# plt.show()

sns.countplot(data=dataset, x='Housing', hue='Sex')
plt.show()

# %% [markdown]
# # Partie 3. Préparation du jeu de données pour notre modélisation (Ingénierie des caractéristiques) (Ensemble)
#
# Maintenant que nous avons exploré certaines des caractéristiques de notre jeu de données, nous devrions évaluer leur qualité et leur potentiel pour extraire des caractéristiques plus informatives en appliquant des connaissances du domaine, ou en combinant les caractéristiques ensemble.
#
# - Y a-t-il des caractéristiques qui pourraient être mieux représentées?
# - Pouvons-nous extraire d'autres caractéristiques à partir de l'ensemble actuel?

# %%
dataset.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
# L'age pourrait-il etre mieux représenté?

# Voyons comment l`age est distribué
sns.displot(dataset['Age'])
plt.show()

# Divisons l'âge en catégories
interval = (18, 25, 35, 60, 120)
cats = ['Young Adult', 'Adult', 'Senior', 'Elder']
dataset["Age_cat"] = pd.cut(dataset['Age'], interval, labels=cats)

# %%
dataset.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk      Age_cat
# 0         6             radio/TV  good        Elder
# 1        48             radio/TV   bad  Young Adult
# 2        12            education  good       Senior
# 3        42  furniture/equipment  good       Senior
# 4        24                  car   bad       Senior

# %%
# Le montant du crédit pourrait-il mieux representé?
# Voyons comment le montant du crédit est distribué
sns.displot(dataset['Credit amount'])
plt.show()

# %%
# Une autre façon de représenter les distributions numériques à longue traine est de les transformer
# en utilisant, par exemple, une fonction log
sns.displot(np.log10(dataset['Credit amount']))
plt.show()

# Applique la nouvelle distribution au jeu de données
dataset['Credit amount'] = np.log10(dataset['Credit amount'])

# %%
dataset.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little       3.067815
# 1   22  female    2     own          little         moderate       3.774590
# 2   49    male    1     own          little              NaN       3.321391
# 3   45    male    2    free          little           little       3.896636
# 4   53    male    2    free          little           little       3.687529
#
#    Duration              Purpose  Risk      Age_cat
# 0         6             radio/TV  good        Elder
# 1        48             radio/TV   bad  Young Adult
# 2        12            education  good       Senior
# 3        42  furniture/equipment  good       Senior
# 4        24                  car   bad       Senior

# %%
# Gérer les valeurs manquantes de Compte d'épargne et compte courant
dataset['Saving accounts'] = dataset['Saving accounts'].fillna('no_inf')
dataset['Checking account'] = dataset['Checking account'].fillna('no_inf')

# %%
dataset.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own          no_inf           little       3.067815
# 1   22  female    2     own          little         moderate       3.774590
# 2   49    male    1     own          little           no_inf       3.321391
# 3   45    male    2    free          little           little       3.896636
# 4   53    male    2    free          little           little       3.687529
#
#    Duration              Purpose  Risk      Age_cat
# 0         6             radio/TV  good        Elder
# 1        48             radio/TV   bad  Young Adult
# 2        12            education  good       Senior
# 3        42  furniture/equipment  good       Senior
# 4        24                  car   bad       Senior

# %% [markdown]
# ### Encodage des caractéristiques catégorielles
#
# Les caractéristiques catégorielles posent un problème aux modèles d'apprentissage automatique:
# - Comment représenter les caractéristiques catégorielles comme Logement = {propriétaire, locataire}?
#
# **Solution 1 - Encodage numérique:** Nous pourrions les représenter en utilisant des valeurs numériques - Logement = {propriétaire = 1, locataire = 2}
#
# | Housing |
# | -- |
# | 1 |
# | 2 |
#
# - Le problème de cette représentation est qu'elle suppose une relation ordonnée:
#  - est-ce que "propriétaire" vient avant "locataire"? Cette question a-t-elle même un sens?
#
# **Solution 2 - Encodage One-Hot:** Au lieu de représenter Logement = {propriétaire = 1, locataire = 2}, nous transformons Logement en une matrice:
#
#
# | Housing_own | Housing_free |
# | -- | -- |
# | 1 | 0 |
# | 0 | 1 |

# %%
# Scikit-learn a un encodeur OneHot adéquat que nous pourrions utiliser dans notre pipeline. Cependant,
# pour des raisons d'exploration, l'encodeur OneHot de Scikit-learn ne garde pas trace de la valeur

def one_hot_encoder(df, column_name, exclude_col = False):
    merged_df = df.merge(pd.get_dummies(df[column_name], drop_first=False, prefix=column_name), left_index=True, right_index=True)
    if exclude_col:
        del merged_df[column_name] # Exclure la colonne d'origine
    return merged_df

# %%
# Avant d'apliquer l'encodage OneHot
dataset.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk', 'Age_cat'],
#       dtype='object')

# %%
# Comme le changement va être plus signifiant. On va copier le dataframe et sauvegarder dans une autre variable (on peut toujours comparer le deux)  
dataset_ready = dataset.copy()

category_features = ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose', 'Risk', 'Age_cat']

for cat in category_features:
    dataset_ready = one_hot_encoder(dataset_ready, cat, exclude_col=True)

# %%
# Avant de l'Encodage OneHot 
dataset_ready.columns
# Out:
# Index(['Age', 'Job', 'Credit amount', 'Duration', 'Sex_female', 'Sex_male',
#        'Housing_free', 'Housing_own', 'Housing_rent', 'Saving accounts_little',
#        'Saving accounts_moderate', 'Saving accounts_no_inf',
#        'Saving accounts_quite rich', 'Saving accounts_rich',
#        'Checking account_little', 'Checking account_moderate',
#        'Checking account_no_inf', 'Checking account_rich', 'Purpose_business',
#        'Purpose_car', 'Purpose_domestic appliances', 'Purpose_education',
#        'Purpose_furniture/equipment', 'Purpose_radio/TV', 'Purpose_repairs',
#        'Purpose_vacation/others', 'Risk_bad', 'Risk_good',
#        'Age_cat_Young Adult', 'Age_cat_Adult', 'Age_cat_Senior',
#        'Age_cat_Elder'],
#       dtype='object')

# %%
dataset_ready.head()
# Out:
#    Age  Job  Credit amount  Duration  Sex_female  Sex_male  Housing_free  \
# 0   67    2       3.067815         6       False      True         False
# 1   22    2       3.774590        48        True     False         False
# 2   49    1       3.321391        12       False      True         False
# 3   45    2       3.896636        42       False      True          True
# 4   53    2       3.687529        24       False      True          True
#
#    Housing_own  Housing_rent  Saving accounts_little  ...  \
# 0         True         False                   False  ...
# 1         True         False                    True  ...
# 2         True         False                    True  ...
# 3        False         False                    True  ...
# 4        False         False                    True  ...
#
#    Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                        False              True            False
# 1                        False              True            False
# 2                        False             False            False
# 3                         True             False            False
# 4                        False             False            False
#
#    Purpose_vacation/others  Risk_bad  Risk_good  Age_cat_Young Adult  \
# 0                    False     False       True                False
# 1                    False      True      False                 True
# 2                    False     False       True                False
# 3                    False     False       True                False
# 4                    False      True      False                False
#
#    Age_cat_Adult  Age_cat_Senior  Age_cat_Elder
# 0          False           False           True
# 1          False           False          False
# 2          False            True          False
# 3          False            True          False
# 4          False            True          False
#
# [5 rows x 32 columns]

# %% [markdown]
# # Partie 4. Prédiction du risque (Modelling)
#
# Tout d'abord, nous allons diviser le jeu de données en:
# - Caractéristiques (X) et variable cible (y)
# - Ensemble d'entraînement (75%) et ensemble de test (25%)

# %%
# Importation des bibliothèques que nous utiliserons dans cette partie de la classe
from sklearn.model_selection import train_test_split, KFold, cross_val_score # pour séparer les données
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report, f1_score, precision_score, recall_score #Pour évaluer notre modèle

from sklearn.model_selection import GridSearchCV

# Modèles d'algorithmes à comparer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
# TODO: Ajouter ici tout nouveau modèle que vous souhaitez essayer (ANN, etc.)

# Création des variables X et y
dataset_ready_x = dataset_ready.drop(['Risk_bad', 'Risk_good', 'Age', 'Sex_male'], axis='columns')
X = dataset_ready_x.values
feature_names = dataset_ready_x.columns

y = dataset_ready['Risk_bad'].values

# Séparation de X et y en version d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %% [markdown]
# ## Classifieurs indépendants

# %% [markdown]
# Ensuite, nous expérimenterons avec plusieurs modèles pour choisir quelques-uns appropriés. Voici les modèles que nous allons expérimenter:
# - [RandomForestClassifier](https://scikit-learn.org/stable/modules/ensemble.html#forests-of-randomized-trees)
# - [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression)
# - [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier)
# - [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier)
# - [GaussianNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB)
# - [Support Vector Machine Classifier (SVC)](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)
# - [MLPClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)
# - [XGBoost](https://xgboost.readthedocs.io/en/stable/python/python_api.html#module-xgboost.sklearn)
# - Plus de classificateurs peuvent être trouvés [ici](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning)

# %%
# Expérimentez différents modèles 
classifier = LogisticRegression(solver='liblinear')
# classifier = KNeighborsClassifier()
# classifier = DecisionTreeClassifier()
# classifier = GaussianNB()
# classifier = RandomForestClassifier()
# classifier = SVC()
# classifier = MLPClassifier()
# classifier = XGBClassifier()
# classifier = [...]

classifier_name = classifier.__class__.__name__

scoring_type = 'accuracy'
kfold = KFold(n_splits=5, random_state=42, shuffle=True) # Assurez que toutes les méthodes sont évaluées dans les mêmes données

score = cross_val_score(classifier, X_train, y_train, cv=kfold, scoring=scoring_type)
print(f'Average {scoring_type} performance of the {classifier_name} model = {np.mean(score)}')
# Out:
# Average accuracy performance of the LogisticRegression model = 0.7293333333333333

# %% [markdown]
# ## AutoML (FLAML)
#
# _A Fast Library for Automated Machine Learning & Tuning_
#
# See https://github.com/microsoft/FLAML
# https://microsoft.github.io/FLAML/
#
# !pip install "flaml[automl]"

# %%
from flaml import AutoML

automl = AutoML()
automl.fit(X_train, y_train, task="classification", time_budget=180, metric='accuracy')
# Out:
# [flaml.automl.logger: 10-06 16:00:04] {1728} INFO - task = classification
# [flaml.automl.logger: 10-06 16:00:04] {1739} INFO - Evaluation method: cv
# [flaml.automl.logger: 10-06 16:00:04] {1838} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 10-06 16:00:04] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'lrl1']
# [flaml.automl.logger: 10-06 16:00:04] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:04] {2393} INFO - Estimated sufficient time budget=564s. Estimated necessary time budget=13s.
# [flaml.automl.logger: 10-06 16:00:04] {2442} INFO -  at 0.1s,	estimator lgbm's best error=0.2905,	best estimator lgbm's best error=0.2905
# [flaml.automl.logger: 10-06 16:00:04] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:04] {2442} INFO -  at 0.1s,	estimator lgbm's best error=0.2835,	best estimator lgbm's best error=0.2835
# [flaml.automl.logger: 10-06 16:00:04] {2258} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:04] {2442} INFO -  at 0.2s,	estimator lgbm's best error=0.2835,	best estimator lgbm's best error=0.2835
# [flaml.automl.logger: 10-06 16:00:04] {2258} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:04] {2442} INFO -  at 0.2s,	estimator lgbm's best error=0.2825,	best estimator lgbm's best error=0.2825
# [flaml.automl.logger: 10-06 16:00:04] {2258} INFO - iteration 4, current learner sgd
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.2s,	estimator sgd's best error=0.3353,	best estimator lgbm's best error=0.2825
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 5, current learner sgd
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.3s,	estimator sgd's best error=0.3251,	best estimator lgbm's best error=0.2825
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.4s,	estimator xgboost's best error=0.2905,	best estimator lgbm's best error=0.2825
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.4s,	estimator lgbm's best error=0.2825,	best estimator lgbm's best error=0.2825
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.5s,	estimator lgbm's best error=0.2818,	best estimator lgbm's best error=0.2818
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.5s,	estimator lgbm's best error=0.2788,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.6s,	estimator lgbm's best error=0.2788,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.7s,	estimator lgbm's best error=0.2788,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.7s,	estimator xgboost's best error=0.2905,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.7s,	estimator xgboost's best error=0.2905,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 0.8s,	estimator xgboost's best error=0.2813,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 1.0s,	estimator extra_tree's best error=0.2800,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 1.1s,	estimator rf's best error=0.3022,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:05] {2442} INFO -  at 1.2s,	estimator lgbm's best error=0.2788,	best estimator lgbm's best error=0.2788
# [flaml.automl.logger: 10-06 16:00:05] {2258} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 1.3s,	estimator extra_tree's best error=0.2709,	best estimator extra_tree's best error=0.2709
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 1.5s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 1.7s,	estimator extra_tree's best error=0.2709,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 1.9s,	estimator rf's best error=0.2904,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 1.9s,	estimator xgboost's best error=0.2813,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:06] {2442} INFO -  at 2.1s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:06] {2258} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.3s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.5s,	estimator extra_tree's best error=0.2657,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 26, current learner sgd
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.5s,	estimator sgd's best error=0.3251,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.7s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 28, current learner rf
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.8s,	estimator rf's best error=0.2904,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 29, current learner sgd
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.8s,	estimator sgd's best error=0.3025,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 30, current learner sgd
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 2.9s,	estimator sgd's best error=0.2708,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:07] {2442} INFO -  at 3.1s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:07] {2258} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.5s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 33, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.6s,	estimator sgd's best error=0.2708,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 34, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.6s,	estimator sgd's best error=0.2607,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.7s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 36, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.8s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 37, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 3.8s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 4.0s,	estimator extra_tree's best error=0.2657,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 39, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 4.0s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 4.2s,	estimator rf's best error=0.2893,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 41, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 4.2s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 42, current learner sgd
# [flaml.automl.logger: 10-06 16:00:08] {2442} INFO -  at 4.2s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:08] {2258} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 4.5s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 44, current learner sgd
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 4.6s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 4.6s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 46, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 4.8s,	estimator extra_tree's best error=0.2657,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 4.9s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 48, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 5.1s,	estimator extra_tree's best error=0.2657,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:09] {2442} INFO -  at 5.2s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:09] {2258} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:10] {2442} INFO -  at 5.3s,	estimator xgboost's best error=0.2813,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:10] {2258} INFO - iteration 51, current learner sgd
# [flaml.automl.logger: 10-06 16:00:10] {2442} INFO -  at 5.3s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:10] {2258} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:10] {2442} INFO -  at 5.8s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:10] {2258} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 10-06 16:00:10] {2442} INFO -  at 5.9s,	estimator rf's best error=0.2893,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:10] {2258} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:10] {2442} INFO -  at 6.2s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:10] {2258} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.3s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 56, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.5s,	estimator extra_tree's best error=0.2584,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.7s,	estimator rf's best error=0.2893,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.8s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.8s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.9s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 6.9s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 7.0s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 7.0s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 7.1s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 7.1s,	estimator xgboost's best error=0.2482,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:11] {2442} INFO -  at 7.2s,	estimator xgboost's best error=0.2480,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:11] {2258} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:12] {2442} INFO -  at 7.4s,	estimator extra_tree's best error=0.2584,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:12] {2258} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:12] {2442} INFO -  at 7.5s,	estimator xgboost's best error=0.2480,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:12] {2258} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:12] {2442} INFO -  at 7.7s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:12] {2258} INFO - iteration 70, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:12] {2442} INFO -  at 7.9s,	estimator extra_tree's best error=0.2560,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:12] {2258} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:12] {2442} INFO -  at 8.1s,	estimator extra_tree's best error=0.2560,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:12] {2258} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:13] {2442} INFO -  at 8.3s,	estimator extra_tree's best error=0.2560,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:13] {2258} INFO - iteration 73, current learner sgd
# [flaml.automl.logger: 10-06 16:00:13] {2442} INFO -  at 8.3s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:13] {2258} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:13] {2442} INFO -  at 8.5s,	estimator extra_tree's best error=0.2525,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:13] {2258} INFO - iteration 75, current learner sgd
# [flaml.automl.logger: 10-06 16:00:13] {2442} INFO -  at 8.5s,	estimator sgd's best error=0.2589,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:13] {2258} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:13] {2442} INFO -  at 8.9s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:13] {2258} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 9.3s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 78, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 9.3s,	estimator sgd's best error=0.2549,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 79, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 9.5s,	estimator extra_tree's best error=0.2525,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 9.7s,	estimator xgboost's best error=0.2480,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 81, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 9.7s,	estimator sgd's best error=0.2549,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 82, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.0s,	estimator extra_tree's best error=0.2525,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 83, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.0s,	estimator sgd's best error=0.2549,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 84, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.0s,	estimator sgd's best error=0.2549,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 85, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.1s,	estimator sgd's best error=0.2549,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 86, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.1s,	estimator sgd's best error=0.2543,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 87, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.1s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 88, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.1s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 89, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.2s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 90, current learner sgd
# [flaml.automl.logger: 10-06 16:00:14] {2442} INFO -  at 10.2s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:14] {2258} INFO - iteration 91, current learner sgd
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.2s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 92, current learner sgd
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.3s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 93, current learner sgd
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.3s,	estimator sgd's best error=0.2485,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 94, current learner sgd
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.4s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 95, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.5s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 96, current learner sgd
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.5s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.6s,	estimator xgboost's best error=0.2480,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 98, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.7s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 99, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 10.9s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 100, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:15] {2442} INFO -  at 11.1s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:15] {2258} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:16] {2442} INFO -  at 11.3s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:16] {2258} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:16] {2442} INFO -  at 11.6s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:16] {2258} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:16] {2442} INFO -  at 12.2s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:16] {2258} INFO - iteration 104, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 12.3s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 105, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 12.5s,	estimator extra_tree's best error=0.2467,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 12.8s,	estimator extra_tree's best error=0.2466,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 107, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 12.9s,	estimator xgb_limitdepth's best error=0.2694,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 108, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 13.0s,	estimator xgb_limitdepth's best error=0.2637,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 109, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 13.1s,	estimator xgb_limitdepth's best error=0.2623,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 110, current learner sgd
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 13.1s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 111, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:17] {2442} INFO -  at 13.2s,	estimator xgb_limitdepth's best error=0.2623,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:17] {2258} INFO - iteration 112, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 13.3s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 113, current learner sgd
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 13.4s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 13.5s,	estimator xgb_limitdepth's best error=0.2623,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 115, current learner sgd
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 13.5s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 116, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 13.6s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 117, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 14.2s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 118, current learner sgd
# [flaml.automl.logger: 10-06 16:00:18] {2442} INFO -  at 14.2s,	estimator sgd's best error=0.2483,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:18] {2258} INFO - iteration 119, current learner extra_tree
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.4s,	estimator extra_tree's best error=0.2466,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 120, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.6s,	estimator lgbm's best error=0.2465,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 121, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.7s,	estimator xgb_limitdepth's best error=0.2588,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 122, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.8s,	estimator xgb_limitdepth's best error=0.2588,	best estimator lgbm's best error=0.2465
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 123, current learner sgd
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.8s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 124, current learner sgd
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.8s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 125, current learner sgd
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 14.8s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:19] {2442} INFO -  at 15.1s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:19] {2258} INFO - iteration 127, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.2s,	estimator xgboost's best error=0.2480,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 128, current learner xgboost
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.3s,	estimator xgboost's best error=0.2480,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 129, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.3s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 130, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.3s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 131, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 132, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 133, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 134, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 135, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 136, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 137, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 138, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 139, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.8s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 140, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 141, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 142, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 143, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 144, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 15.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 145, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 16.0s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 146, current learner sgd
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 16.0s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 147, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:20] {2442} INFO -  at 16.1s,	estimator xgb_limitdepth's best error=0.2588,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:20] {2258} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 16.3s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 149, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 16.3s,	estimator xgb_limitdepth's best error=0.2588,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 150, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 17.0s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 151, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 17.1s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 152, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 17.1s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 153, current learner sgd
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 17.2s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 154, current learner sgd
# [flaml.automl.logger: 10-06 16:00:21] {2442} INFO -  at 17.2s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:21] {2258} INFO - iteration 155, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.3s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 156, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.3s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 157, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 158, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 159, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.5s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 160, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.5s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 161, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.6s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 162, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.7s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 163, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.7s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 164, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.7s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 165, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.7s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 166, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.8s,	estimator xgb_limitdepth's best error=0.2519,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 167, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.8s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 168, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 169, current learner sgd
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 17.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 170, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:22] {2442} INFO -  at 18.0s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:22] {2258} INFO - iteration 171, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.3s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 172, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.4s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 173, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.5s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 174, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.6s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 175, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.6s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 176, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.7s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 177, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.7s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 178, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.7s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 179, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.9s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 180, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 181, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 18.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 182, current learner sgd
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 19.0s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 183, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 19.1s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 184, current learner rf
# [flaml.automl.logger: 10-06 16:00:23] {2442} INFO -  at 19.2s,	estimator rf's best error=0.2893,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:23] {2258} INFO - iteration 185, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.3s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 186, current learner sgd
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.4s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 187, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.4s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 188, current learner sgd
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 189, current learner rf
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.6s,	estimator rf's best error=0.2677,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 190, current learner rf
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.8s,	estimator rf's best error=0.2677,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 191, current learner sgd
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 19.9s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 192, current learner rf
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 20.1s,	estimator rf's best error=0.2677,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 193, current learner sgd
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 20.1s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 194, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:24] {2442} INFO -  at 20.2s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:24] {2258} INFO - iteration 195, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.2s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 196, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.3s,	estimator xgb_limitdepth's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 197, current learner rf
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.5s,	estimator rf's best error=0.2669,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 198, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 199, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 200, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.5s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 201, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.6s,	estimator sgd's best error=0.2442,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 202, current learner lgbm
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.7s,	estimator lgbm's best error=0.2465,	best estimator sgd's best error=0.2442
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 203, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 20.9s,	estimator xgb_limitdepth's best error=0.2414,	best estimator xgb_limitdepth's best error=0.2414
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 204, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 21.1s,	estimator xgb_limitdepth's best error=0.2414,	best estimator xgb_limitdepth's best error=0.2414
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 205, current learner sgd
# [flaml.automl.logger: 10-06 16:00:25] {2442} INFO -  at 21.1s,	estimator sgd's best error=0.2442,	best estimator xgb_limitdepth's best error=0.2414
# [flaml.automl.logger: 10-06 16:00:25] {2258} INFO - iteration 206, current learner sgd
# ...
# [flaml.automl.logger: 10-06 16:02:44] {2258} INFO - iteration 638, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:44] {2442} INFO -  at 159.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:44] {2258} INFO - iteration 639, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:46] {2442} INFO -  at 161.4s,	estimator xgb_limitdepth's best error=0.2329,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:46] {2258} INFO - iteration 640, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:46] {2442} INFO -  at 161.5s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:46] {2258} INFO - iteration 641, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:47] {2442} INFO -  at 162.3s,	estimator xgb_limitdepth's best error=0.2329,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:47] {2258} INFO - iteration 642, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:47] {2442} INFO -  at 162.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:47] {2258} INFO - iteration 643, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:49] {2442} INFO -  at 164.4s,	estimator xgb_limitdepth's best error=0.2329,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:49] {2258} INFO - iteration 644, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:49] {2442} INFO -  at 164.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:49] {2258} INFO - iteration 645, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:49] {2442} INFO -  at 164.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:49] {2258} INFO - iteration 646, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:49] {2442} INFO -  at 164.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:49] {2258} INFO - iteration 647, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:49] {2442} INFO -  at 164.9s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2329
# [flaml.automl.logger: 10-06 16:02:49] {2258} INFO - iteration 648, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 165.7s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 649, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 165.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 650, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 165.8s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 651, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 166.0s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 652, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 166.1s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 653, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:50] {2442} INFO -  at 166.1s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:50] {2258} INFO - iteration 654, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 166.3s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 655, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 166.5s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 656, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 166.5s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 657, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 166.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 658, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 166.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 659, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 167.0s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 660, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:51] {2442} INFO -  at 167.1s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:51] {2258} INFO - iteration 661, current learner lrl1
# [flaml.automl.logger: 10-06 16:02:52] {2442} INFO -  at 167.3s,	estimator lrl1's best error=0.2387,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:52] {2258} INFO - iteration 662, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:52] {2442} INFO -  at 167.4s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:52] {2258} INFO - iteration 663, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:52] {2442} INFO -  at 167.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:52] {2258} INFO - iteration 664, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:52] {2442} INFO -  at 167.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:52] {2258} INFO - iteration 665, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 168.4s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 666, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 168.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 667, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 168.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 668, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 169.0s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 669, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 169.1s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 670, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:53] {2442} INFO -  at 169.2s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:53] {2258} INFO - iteration 671, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:54] {2442} INFO -  at 169.3s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:54] {2258} INFO - iteration 672, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:54] {2442} INFO -  at 169.8s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:54] {2258} INFO - iteration 673, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:56] {2442} INFO -  at 171.7s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:56] {2258} INFO - iteration 674, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:56] {2442} INFO -  at 172.0s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:56] {2258} INFO - iteration 675, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:57] {2442} INFO -  at 172.3s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:57] {2258} INFO - iteration 676, current learner lgbm
# [flaml.automl.logger: 10-06 16:02:57] {2442} INFO -  at 172.7s,	estimator lgbm's best error=0.2445,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:57] {2258} INFO - iteration 677, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:57] {2442} INFO -  at 173.2s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:57] {2258} INFO - iteration 678, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:58] {2442} INFO -  at 173.3s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:58] {2258} INFO - iteration 679, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:58] {2442} INFO -  at 173.4s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:58] {2258} INFO - iteration 680, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:58] {2442} INFO -  at 174.2s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:58] {2258} INFO - iteration 681, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:02:59] {2442} INFO -  at 174.8s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:59] {2258} INFO - iteration 682, current learner lrl1
# [flaml.automl.logger: 10-06 16:02:59] {2442} INFO -  at 174.9s,	estimator lrl1's best error=0.2387,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:59] {2258} INFO - iteration 683, current learner xgboost
# [flaml.automl.logger: 10-06 16:02:59] {2442} INFO -  at 175.0s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:02:59] {2258} INFO - iteration 684, current learner lgbm
# [flaml.automl.logger: 10-06 16:03:00] {2442} INFO -  at 175.5s,	estimator lgbm's best error=0.2445,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:00] {2258} INFO - iteration 685, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:00] {2442} INFO -  at 175.9s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:00] {2258} INFO - iteration 686, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:01] {2442} INFO -  at 177.0s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:01] {2258} INFO - iteration 687, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:01] {2442} INFO -  at 177.2s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:01] {2258} INFO - iteration 688, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:02] {2442} INFO -  at 177.3s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:02] {2258} INFO - iteration 689, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:02] {2442} INFO -  at 178.1s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:02] {2258} INFO - iteration 690, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:03] {2442} INFO -  at 178.7s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:03] {2258} INFO - iteration 691, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:03] {2442} INFO -  at 179.1s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:03] {2258} INFO - iteration 692, current learner xgb_limitdepth
# [flaml.automl.logger: 10-06 16:03:04] {2442} INFO -  at 179.6s,	estimator xgb_limitdepth's best error=0.2323,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:04] {2258} INFO - iteration 693, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:04] {2442} INFO -  at 179.6s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:04] {2258} INFO - iteration 694, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:04] {2442} INFO -  at 179.7s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:04] {2258} INFO - iteration 695, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:04] {2442} INFO -  at 179.8s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:04] {2258} INFO - iteration 696, current learner xgboost
# [flaml.automl.logger: 10-06 16:03:04] {2442} INFO -  at 180.0s,	estimator xgboost's best error=0.2372,	best estimator xgb_limitdepth's best error=0.2323
# [flaml.automl.logger: 10-06 16:03:04] {2685} INFO - retrain xgb_limitdepth for 0.2s
# [flaml.automl.logger: 10-06 16:03:04] {2688} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=np.float64(0.48908333341027815),
#               colsample_bynode=None,
#               colsample_bytree=np.float64(0.7986228043852982), device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None,
#               learning_rate=np.float64(0.27323655926425944), max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=np.float64(0.3511282865718242), missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=72,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 10-06 16:03:04] {1985} INFO - fit succeeded
# [flaml.automl.logger: 10-06 16:03:04] {1986} INFO - Time taken to find the best model: 165.65140676498413

# %%
automl
# Out:
# AutoML(append_log=False, auto_augment=True, custom_hp={},
#        cv_score_agg_func=None, early_stop=False, ensemble=False,
#        estimator_list='auto', eval_method='auto', fit_kwargs_by_estimator={},
#        force_cancel=False, free_mem_ratio=0, hpo_method='auto',
#        keep_search_state=False, learner_selector='sample', log_file_name='',
#        log_training_metric=False, log_type='better', max_iter=None,
#        mem_thres=4294967296, metric='auto', metric_constraints=[],
#        min_sample_size=10000, mlflow_exp_name=None, mlflow_logging=True,
#        model_history=False, n_concurrent_trials=1, n_jobs=-1, n_splits=5,
#        pred_time_limit=inf, preserve_checkpoint=True, ...)

# %%
# Print the best model and its parameters
print(automl.best_estimator)
print(automl.best_config)
# Out:
# xgb_limitdepth
# {'n_estimators': 72, 'max_depth': 7, 'min_child_weight': np.float64(0.3511282865718242), 'learning_rate': np.float64(0.27323655926425944), 'subsample': np.float64(0.7245303466863017), 'colsample_bylevel': np.float64(0.48908333341027815), 'colsample_bytree': np.float64(0.7986228043852982), 'reg_alpha': np.float64(3.001024163238421), 'reg_lambda': np.float64(18.282295462121635)}

# %%
# Prédire les données de test
y_pred = automl.predict(X_test)
print(f"Accuracy of {automl.best_estimator}'s prediction is {accuracy_score(y_test,y_pred)}")
# Out:
# Accuracy of xgb_limitdepth's prediction is 0.756

# %% [markdown]
# # Partie 6a. Évaluation des performances des modèles - Prédiction de l'ensemble de test
# Nous avons vu que de nombreux modèles ont une bonne précision dans nos données d'entraînement. **Mais à quel point nos modèles sont-ils réellement bons?**
#
# Regardons à quel point notre modèle prédit les données de test non vues.

# %%
# Test la qualité de la prédiction du modèle 

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# Montre le résultat
print(f"Accuracy of our model's prediction {accuracy_score(y_test,y_pred)}")
# Out:
# Accuracy of our model's prediction 0.736

# %%
# Prevu
print(f'Credit prevu pour le premier 5 utilisateur a le jeu de données {classifier.predict(X_test[0:5])}')

# Actuel
print(f'Actuel données {y_test[0:5]}')
# Out:
# Credit prevu pour le premier 5 utilisateur a le jeu de données [ True False False False False]
# Actuel données [ True False False False False]

# %% [markdown]
# # Part 6b. L'Évaluation de performance du modèle - Configuration des modèles de référence
#
# Exémple de modèles de référence:
# - **La plus fréquente** : Comparez avec un modèle qui prévoit toujours un "bon" risque
# - **Uniforme** : Comparez avec un modèle qui prévoit 50/50 bon et mauvais risque (jet de pièce)
# - **Stratifié** : Comparez avec un modèle qui prévoit 70% de bon et 30% de mauvais (au hasard)

# %%
from sklearn.dummy import DummyClassifier

strategies = ['most_frequent', 'uniform', 'stratified']

for strategy in strategies:

    dummy_clf = DummyClassifier(strategy=strategy)
    dummy_clf.fit(X_train, y_train)

    #Testing the dummy model 
    y_pred = dummy_clf.predict(X_test)

    # Check the obtained results
    print(f'Performance du modèle de référence {strategy}, Accuracy = {accuracy_score(y_test,y_pred)} ')
# Out:
# Performance du modèle de référence most_frequent, Accuracy = 0.712
# Performance du modèle de référence uniform, Accuracy = 0.544
# Performance du modèle de référence stratified, Accuracy = 0.532

# %% [markdown]
# # Partie 7. Réévaluation des performances des modèles - Exploration d'autres métriques de performance
#
# Essayons d'évaluer notre modèle en utilisant d'autres métriques de performance:
# - Précision
# - Rappel
# - Score F1 (moyenne harmonique entre la précision et le rappel)

# %%
# Testez la qualité de la précision du modéle 
y_pred = classifier.predict(X_test)

# Verifiez les resultats
print(f"""Performance of our choosen model: 
      \t Accuracy = {accuracy_score(y_test, y_pred)} 
      \t Precision = {precision_score(y_test,y_pred)} 
      \t Recall = {recall_score(y_test, y_pred)} 
      \t F1 = {f1_score(y_test, y_pred)}""")

# print(classification_report(y_test, y_pred))
        
strategies = ['most_frequent', 'uniform', 'stratified']

print(f'\nDUMMY Classifiers (Baseline)')
for strategy in strategies:

    dummy_clf = DummyClassifier(strategy=strategy)
    dummy_clf.fit(X_train, y_train)

    # Le modèle de référence
    y_pred_dummy = dummy_clf.predict(X_test)

    # Vérification des résultats
    print(f"""Performance of {strategy} baseline: 
          Accuracy = {accuracy_score(y_test, y_pred_dummy)} 
          Precision = {precision_score(y_test,y_pred_dummy)} 
          Recall = {recall_score(y_test, y_pred_dummy)} 
          F1 = {f1_score(y_test, y_pred_dummy)}""")
# Out:
# Performance of our choosen model:
#       	 Accuracy = 0.736
#       	 Precision = 0.5625
#       	 Recall = 0.375
#       	 F1 = 0.45
#
# DUMMY Classifiers (Baseline)
# Performance of most_frequent baseline:
#           Accuracy = 0.712
#           Precision = 0.0
#           Recall = 0.0
#           F1 = 0.0
# Performance of uniform baseline:
#           Accuracy = 0.512
#           Precision = 0.288135593220339
#           Recall = 0.4722222222222222
#           F1 = 0.35789473684210527
# Performance of stratified baseline:
#           Accuracy = 0.544
#           Precision = 0.26136363636363635
#           Recall = 0.3194444444444444
#           F1 = 0.2875
# /Users/magnin/miniconda3/envs/mgl7320/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
## Legacy code
# from sklearn.metrics import plot_confusion_matrix
# Plot the confusion matrix
# plot_confusion_matrix(classifier, X_test, y_test)


# Exemple d'utilisation de ConfusionMatrixDisplay
# model = RandomForestClassifier()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %% [markdown]
# # Partie 8. Amélioration du modèle (Optionnel)

# %%
# Configuration des paramètres du modèle
# param_grid = {"penalty": ['none', 'l2', 'l1', 'elasticnet'],
#               "solver":['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
#               "max_iter": [100, 300]}

# Création du modèle
# model = LogisticRegression()

# grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='f1', verbose=1)
# grid_search.fit(X_train, y_train)

# %%
# print(grid_search.best_score_)
# print(grid_search.best_params_)

# %%
# best_model = LogisticRegression(penalty='none', solver='sag', max_iter=300)

# Faire 
# best_model.fit(X_train, y_train)

# Verifier la qualité da la prédiction du modèle
# y_pred = best_model.predict(X_test)

# Vérification des résultats
# print(f1_score(y_test,y_pred))
# print(confusion_matrix(y_test, y_pred))
# print(classification_report(y_test, y_pred))

# %% [markdown]
# # Partie 9. Explication du modèle
#
# ## Quelles sont les caractéristiques les plus importantes?
#
# Nous mesurons l'importance d'une caractéristique en calculant l'augmentation de l'erreur de prédiction du modèle après **permutation de la caractéristique** (a.k.a. feature permutation importance).
# - Une caractéristique est "importante" si le mélange de ses valeurs augmente l'erreur du modèle, car dans ce cas le modèle a compté sur la caractéristique pour la prédiction.
# - Une caractéristique est "inimportant" si le mélange de ses valeurs laisse l'erreur du modèle inchangée, car dans ce cas le modèle a ignoré la caractéristique pour la prédiction.

# %%
from sklearn.inspection import permutation_importance

# Permutation importance method (test set)
result = permutation_importance(
    classifier, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots()
fig.set_size_inches(14, 14)
ax.boxplot(
    result.importances[sorted_idx].T, vert=False, labels=feature_names
)
ax.set_title("Permutation Importances (test set)")
fig.tight_layout()
plt.show()
# Out:
# /var/folders/xh/pmp5d_rs6jn5tqk7j92bx92c0000gp/T/ipykernel_95670/2609888765.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(

# %%
# Permutation importance method (train set)
result = permutation_importance(
    classifier, X_train, y_train, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots()
fig.set_size_inches(14, 14)
ax.boxplot(
    result.importances[sorted_idx].T, vert=False, labels=feature_names
)
ax.set_title("Permutation Importances (train set)")
fig.tight_layout()
plt.show()
# Out:
# /var/folders/xh/pmp5d_rs6jn5tqk7j92bx92c0000gp/T/ipykernel_95670/1880685407.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(

# %% [markdown]
# ### Exploration de l'effet de chaque caractéristique
#
# Les étapes suivantes utilisent la bibliothèque ELI5 qui **ne fonctionne pas** avec les classificateurs suivants:
# - GaussianNB
# - MLPClassifier
# - XGBoost (conflit de version de dépendance)

# %%
# import eli5

# eli5.show_weights(classifier, feature_names=feature_names.values, top=100)

# %%
from sklearn.inspection import permutation_importance

# Assuming classifier is already trained and X_test, y_test, and feature_names are defined
result = permutation_importance(classifier, X_test, y_test, n_repeats=30, random_state=42, n_jobs=-1)

# Get the feature importances
importances = result.importances_mean
std = result.importances_std
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_test.shape[1]):
    print(f"{f + 1}. feature {feature_names[indices[f]]} ({importances[indices[f]]})")

# Plot the feature importances
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_test.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(X_test.shape[1]), feature_names[indices], rotation=90)
plt.xlim([-1, X_test.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature Duration (0.03800000000000002)
# 2. feature Checking account_little (0.01666666666666668)
# 3. feature Checking account_no_inf (0.009866666666666675)
# 4. feature Purpose_furniture/equipment (0.00733333333333334)
# 5. feature Saving accounts_little (0.004400000000000004)
# 6. feature Saving accounts_no_inf (0.004400000000000004)
# 7. feature Purpose_education (0.004133333333333337)
# 8. feature Age_cat_Elder (0.002933333333333336)
# 9. feature Purpose_radio/TV (0.002133333333333335)
# 10. feature Saving accounts_moderate (0.0006666666666666673)
# 11. feature Purpose_repairs (0.00013333333333333345)
# 12. feature Saving accounts_quite rich (0.0)
# 13. feature Purpose_domestic appliances (0.0)
# 14. feature Purpose_car (0.0)
# 15. feature Purpose_vacation/others (0.0)
# 16. feature Purpose_business (-0.00013333333333333345)
# 17. feature Checking account_rich (-0.0006666666666666673)
# 18. feature Age_cat_Young Adult (-0.0010666666666666676)
# 19. feature Sex_female (-0.0016000000000000014)
# 20. feature Age_cat_Senior (-0.0022666666666666686)
# 21. feature Credit amount (-0.0030666666666666694)
# 22. feature Saving accounts_rich (-0.00386666666666667)
# 23. feature Age_cat_Adult (-0.005466666666666672)
# 24. feature Housing_own (-0.007066666666666673)
# 25. feature Housing_free (-0.008400000000000008)
# 26. feature Housing_rent (-0.010133333333333343)
# 27. feature Checking account_moderate (-0.010266666666666676)
# 28. feature Job (-0.013600000000000011)

# %% [markdown]
# ### Exploration de la raison pour laquelle le modèle prédit certaines classes
#
# Maintenant que nous avons exploré les caractéristiques les plus importantes du modèle, nous pouvons également essayer d'expliquer **pourquoi** le modèle prédit certaines classes pour certains enregistrements.

# %%
classifier.predict(X_test[2:3])
# Out:
# array([False])

# %%
import numpy as np

# Assuming classifier is already trained and X_test, feature_names are defined
instance = X_test[2].reshape(1, -1)
prediction = classifier.predict(instance)
prediction_proba = classifier.predict_proba(instance)

# Extract feature contributions (coefficients for linear models)
coefficients = classifier.coef_[0]
feature_values = instance[0]
contributions = coefficients * feature_values

# Display the prediction details
print(f"Prediction: {prediction[0]}")
print(f"Prediction Probability: {prediction_proba[0][prediction[0]]}")
print("\nFeature contributions:")

for feature, value, contribution in zip(feature_names, feature_values, contributions):
    print(f"{feature}: value={value}, contribution={contribution}")
# Out:
# Prediction: False
# Prediction Probability: []
#
# Feature contributions:
# Job: value=2, contribution=0.34824300320511437
# Credit amount: value=3.3664229572259727, contribution=-1.0041345042414964
# Duration: value=24, contribution=0.8847076556720546
# Sex_female: value=False, contribution=0.0
# Housing_free: value=False, contribution=0.0
# Housing_own: value=True, contribution=-0.5472507036171564
# Housing_rent: value=False, contribution=-0.0
# Saving accounts_little: value=False, contribution=0.0
# Saving accounts_moderate: value=True, contribution=0.10257762593618797
# Saving accounts_no_inf: value=False, contribution=-0.0
# Saving accounts_quite rich: value=False, contribution=-0.0
# Saving accounts_rich: value=False, contribution=-0.0
# Checking account_little: value=True, contribution=0.6152289117077477
# Checking account_moderate: value=False, contribution=0.0
# Checking account_no_inf: value=False, contribution=-0.0
# Checking account_rich: value=False, contribution=-0.0
# Purpose_business: value=False, contribution=-0.0
# Purpose_car: value=True, contribution=-8.435205948274273e-06
# Purpose_domestic appliances: value=False, contribution=0.0
# Purpose_education: value=False, contribution=0.0
# Purpose_furniture/equipment: value=False, contribution=-0.0
# Purpose_radio/TV: value=False, contribution=-0.0
# Purpose_repairs: value=False, contribution=0.0
# Purpose_vacation/others: value=False, contribution=-0.0
# Age_cat_Young Adult: value=False, contribution=0.0
# Age_cat_Adult: value=True, contribution=0.08747051350749538
# Age_cat_Senior: value=False, contribution=-0.0
# Age_cat_Elder: value=False, contribution=-0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming classifier is already trained and X_test, feature_names are defined
instance = X_test[2].reshape(1, -1)
prediction = classifier.predict(instance)[0]  # Get the scalar value
prediction_proba = classifier.predict_proba(instance)[0]  # Get the first element

# Extract feature contributions (coefficients for linear models)
coefficients = classifier.coef_[0]
feature_values = instance[0]
contributions = coefficients * feature_values

# Sort features by their absolute contribution
sorted_indices = np.argsort(np.abs(contributions))[::-1]
sorted_features = feature_names[sorted_indices]
sorted_contributions = contributions[sorted_indices]
sorted_values = feature_values[sorted_indices]

# Plot the feature contributions
plt.figure(figsize=(10, 10))
plt.barh(sorted_features, sorted_contributions, color='b', align='center')
plt.xlabel('Contribution to Prediction')
plt.title(f'Prediction: {prediction} (Probability: {prediction_proba[int(prediction)]:.2f})')
plt.gca().invert_yaxis()
plt.show()

# %%
eli5.show_prediction(classifier, X_test[2], feature_names=feature_names.values, show_feature_values=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 eli5.show_prediction(classifier, X_test[2], feature_names=feature_names.values, show_feature_values=True)
#
# NameError: name 'eli5' is not defined
